# %%
using Pkg
using DataFrames
using Plots

# %%
println("Hello World")
# Out:
# Hello World

# %%
x = DataFrame(ID=[1,2,3,4,missing], name = ["Alice", "Bob", "Conor", "Dave","Zed"])
y = DataFrame(id=[1,2,5,6,missing], age = [21,22,23,24,99])
x,y
# Out:
# (5×2 DataFrame
#  Row │ ID       name
#      │ Int64?   String
# ─────┼─────────────────
#    1 │       1  Alice
#    2 │       2  Bob
#    3 │       3  Conor
#    4 │       4  Dave
#    5 │ missing  Zed, 5×2 DataFrame
#  Row │ id       age
#      │ Int64?   Int64
# ─────┼────────────────
#    1 │       1     21
#    2 │       2     22
#    3 │       5     23
#    4 │       6     24
#    5 │ missing     99)

# %%
x = 1:10; y = rand(10); # These are the plotting data 
plot(x,y, label="my label")
